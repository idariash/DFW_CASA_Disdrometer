# %% [markdown]
# # Examples for reading and ploting disdrometer data
#
# Ivan Arias Hernandez
#
# 2024/02/13

# %%
import sys
sys.path.append('./code')
import disdrometer_analysis as disdro
import matplotlib.pyplot as plt
import importlib

# %%
importlib.reload(disdro)

Data_Path_radar = '/net/k2/storage/people/idariash/home/CSU/DFW/radar/20240108'

charlie_lat = 32.91365
charlie_lon = -97.05752

swhp_lat = 32.87729
swhp_lon = -97.04658
    
sehp_lat = 32.87544
sehp_lon = -97.03275

Data_Path_disdrometer = '/net/k2/storage/people/idariash/home/CSU/DFW/data/SEHP/20240108'
'/net/k2/storage/people/idariash/home/CSU/DFW/data/Charlie/20240108'
    
Times_radar, Reflectivities_radar = disdro.radar_ref_time_series_lowest_sweeps(
                                                                    Data_Path = Data_Path_radar,
                                                                    disdrometer_lat = sehp_lat, 
                                                                    disdrometer_lon = sehp_lon)
    
Times_disdrometer, Reflectivities_disdrometer = disdro.disdrometer_ref_time_series(
                                                                    Data_Path_disdrometer)
# Out:
# KFWS20240108_150248_V06.ar2v
# KFWS20240108_150656_V06.ar2v
# KFWS20240108_151105_V06.ar2v
# KFWS20240108_151513_V06.ar2v
# KFWS20240108_151921_V06.ar2v
# KFWS20240108_152329_V06.ar2v
# KFWS20240108_152737_V06.ar2v
# KFWS20240108_153146_V06.ar2v
# KFWS20240108_153554_V06.ar2v
# KFWS20240108_154003_V06.ar2v
# KFWS20240108_154411_V06.ar2v
# KFWS20240108_154819_V06.ar2v
# KFWS20240108_155227_V06.ar2v
# KFWS20240108_155635_V06.ar2v
# KFWS20240108_160043_V06.ar2v
# KFWS20240108_160451_V06.ar2v
# KFWS20240108_160858_V06.ar2v
# KFWS20240108_161306_V06.ar2v
# KFWS20240108_161714_V06.ar2v
# KFWS20240108_162122_V06.ar2v
# KFWS20240108_162530_V06.ar2v
# KFWS20240108_162939_V06.ar2v
# KFWS20240108_163348_V06.ar2v
# KFWS20240108_163757_V06.ar2v
# KFWS20240108_164205_V06.ar2v
# KFWS20240108_164614_V06.ar2v
# KFWS20240108_165023_V06.ar2v
# KFWS20240108_165432_V06.ar2v
# KFWS20240108_165840_V06.ar2v
# KFWS20240108_170249_V06.ar2v
# KFWS20240108_170657_V06.ar2v
# KFWS20240108_171104_V06.ar2v
# ...

# %%
importlib.reload(disdro)
fig = disdro.plot_ref_time_series_disdroter_and_radar_mean (Times_radar, 
                                                           Reflectivities_radar, 
                                                           Times_disdrometer, 
                                                           Reflectivities_disdrometer, 
                                                           disdrometer_lat = charlie_lat, 
                                                           disdrometer_lon = charlie_lon)
# Out:
# /top/students/GRAD/ECE/idariash/home/anaconda3/lib/python3.7/site-packages/numpy/core/_asarray.py:85: UserWarning: Warning: converting a masked element to nan.
#   return array(a, dtype, copy=False, order=order)

# %%
importlib.reload(disdro)

fig = disdro.scatter_ref_disdroter_and_radar (Times_radar, 
                                            Reflectivities_radar, 
                                            Times_disdrometer, 
                                            Reflectivities_disdrometer, 
                                            disdrometer_lat = charlie_lat, 
                                            disdrometer_lon = charlie_lon)
# Out:
# ./code/disdrometer_analysis.py:583: UserWarning: Warning: converting a masked element to nan.
#   disdrometer = np.array(Reflectivities_disdrometer_mean)
# /top/students/GRAD/ECE/idariash/home/anaconda3/lib/python3.7/site-packages/numpy/ma/core.py:722: UserWarning: Warning: converting a masked element to nan.
#   data = np.array(a, copy=False, subok=subok)
# /top/students/GRAD/ECE/idariash/home/anaconda3/lib/python3.7/site-packages/numpy/ma/core.py:2795: UserWarning: Warning: converting a masked element to nan.
#   order=order, subok=True, ndmin=ndmin)

# %%
importlib.reload(disdro)
Data_Path = '/net/k2/storage/people/idariash/home/CSU/DFW/data/Charlie/20240108'
'/net/k2/storage/people/idariash/home/CSU/DFW/data/SWHP/tmp'

Dmax = 10
fig = disdro.plot_DSD_falling_velocity_many(Data_Path, Dmax)

# %%
importlib.reload(disdro)

Data_Path_radar = '/net/k2/storage/people/idariash/home/CSU/DFW/radar/20240108'
charlie_lat = 32.91365
charlie_lon = -97.05752
Data_Path_disdrometer = '/net/k2/storage/people/idariash/home/CSU/DFW/data/Charlie/20240108_test'
fig = disdro.plot_ref_time_series_disdrother_and_radar_mean (Data_Path_disdrometer, 
                                                        Data_Path_radar, 
                                                        disdrometer_lat = charlie_lat, 
                                                        disdrometer_lon = charlie_lon)
# Out:
# KFWS20240108_150248_V06.ar2v
# KFWS20240108_150656_V06.ar2v
# KFWS20240108_151105_V06.ar2v
# KFWS20240108_151513_V06.ar2v
# KFWS20240108_151921_V06.ar2v
# KFWS20240108_152329_V06.ar2v
# KFWS20240108_152737_V06.ar2v
# KFWS20240108_153146_V06.ar2v
# KFWS20240108_153554_V06.ar2v
# KFWS20240108_154003_V06.ar2v
# KFWS20240108_154411_V06.ar2v
# KFWS20240108_154819_V06.ar2v
# KFWS20240108_155227_V06.ar2v
# KFWS20240108_155635_V06.ar2v
# KFWS20240108_160043_V06.ar2v
# KFWS20240108_160451_V06.ar2v
# KFWS20240108_160858_V06.ar2v
# KFWS20240108_161306_V06.ar2v
# KFWS20240108_161714_V06.ar2v
# KFWS20240108_162122_V06.ar2v
# KFWS20240108_162530_V06.ar2v
# KFWS20240108_162939_V06.ar2v
# KFWS20240108_163348_V06.ar2v
# KFWS20240108_163757_V06.ar2v
# KFWS20240108_164205_V06.ar2v
# KFWS20240108_164614_V06.ar2v
# KFWS20240108_165023_V06.ar2v
# KFWS20240108_165432_V06.ar2v
# KFWS20240108_165840_V06.ar2v
# KFWS20240108_170249_V06.ar2v
# KFWS20240108_170657_V06.ar2v
# KFWS20240108_171104_V06.ar2v
# ...

# %%
importlib.reload(disdro)

Data_Path_radar = '/net/k2/storage/people/idariash/home/CSU/DFW/radar/20240108'
charlie_lat = 32.91365
charlie_lon = -97.05752
Data_Path_disdrometer = '/net/k2/storage/people/idariash/home/CSU/DFW/data/Charlie/20240108_test'
fig = disdro.plot_ref_time_series_disdrother_and_radar (Data_Path_disdrometer, 
                                                        Data_Path_radar, 
                                                        disdrometer_lat = charlie_lat, 
                                                        disdrometer_lon = charlie_lon)
# Out:
# /top/students/GRAD/ECE/idariash/home/anaconda3/lib/python3.7/site-packages/numpy/core/_asarray.py:138: UserWarning: Warning: converting a masked element to nan.
#   return array(a, dtype, copy=False, order=order, subok=True)
# /top/students/GRAD/ECE/idariash/home/anaconda3/lib/python3.7/site-packages/pydsd/DropSizeDistribution.py:437: RuntimeWarning: invalid value encountered in double_scalars
#   run = (0.5 * cum_W[-1] - cum_W[cross_pt]) / slope
# /top/students/GRAD/ECE/idariash/home/anaconda3/lib/python3.7/site-packages/pytmatrix/psd.py:183: RuntimeWarning: invalid value encountered in greater
#   psd[(D > self.D_max) | (D==0.0)] = 0.0
# ./code/disdrometer_analysis.py:315: RuntimeWarning: divide by zero encountered in log10
#   plt.gca().xaxis.set_major_formatter(hh_mm)
# /top/students/GRAD/ECE/idariash/home/anaconda3/lib/python3.7/site-packages/pytmatrix/psd.py:174: RuntimeWarning: invalid value encountered in double_scalars
# ...

# %%
importlib.reload(disdro)
filename = '/net/k2/storage/people/idariash/home/CSU/DFW/radar/KFWS20240108_173658_V06'
sweep = 0
fig = disdro.plot_nexrad_ppi_ref_near_DFW_airport(filename, sweep)

# %%
importlib.reload(disdro)
filename = '/net/k2/storage/people/idariash/home/CSU/DFW/radar/KFWS20240108_173658_V06'
sweep = 0
fig = disdro.plot_nexrad_ppi_ref(filename, sweep)

# %%
importlib.reload(disdro)
Data_Path = '/net/k2/storage/people/idariash/home/CSU/DFW/data/SWHP/tmp'
'/net/k2/storage/people/idariash/home/CSU/DFW/data/20240108'

fig = disdro.plot_time_series(Data_Path)
# Out:
# /top/students/GRAD/ECE/idariash/home/anaconda3/lib/python3.7/site-packages/numpy/core/_asarray.py:138: UserWarning: Warning: converting a masked element to nan.
#   return array(a, dtype, copy=False, order=order, subok=True)
# /top/students/GRAD/ECE/idariash/home/anaconda3/lib/python3.7/site-packages/pydsd/DropSizeDistribution.py:437: RuntimeWarning: invalid value encountered in double_scalars
#   run = (0.5 * cum_W[-1] - cum_W[cross_pt]) / slope
# /top/students/GRAD/ECE/idariash/home/anaconda3/lib/python3.7/site-packages/pytmatrix/psd.py:183: RuntimeWarning: invalid value encountered in greater
#   psd[(D > self.D_max) | (D==0.0)] = 0.0
# /top/students/GRAD/ECE/idariash/home/anaconda3/lib/python3.7/site-packages/pytmatrix/psd.py:174: RuntimeWarning: invalid value encountered in double_scalars
#   self.nf = Nw * 6.0/3.67**4 * (3.67+mu)**(mu+4)/gamma(mu+4)
# ./code/disdrometer_analysis.py:264: MatplotlibDeprecationWarning:
# ...

# %%
importlib.reload(disdro)

filename = '/net/k2/storage/people/idariash/home/CSU/DFW/data/SWHP/test/DIS_20240108_171901.txt'

'/net/k2/storage/people/idariash/home/CSU/DFW/data/Charlie/20240108/DIS_20240108_171401.txt'
'/net/k2/storage/projects/DistroDFW/DFW/UMASS/SEHP/20240108/DIS_20240108_173401.txt'
'/net/k2/storage/projects/DistroDFW/DFW/charlie/2024/01/08/DIS_20240108_173401.txt'
'/net/k2/storage/projects/DistroDFW/DFW/charlie/2024/01/08/DIS_20240108_173401.txt'
'/net/k2/storage/projects/DistroDFW/DFW/charlie/2024/01/08/DIS_20240108_173501.txt'
'/net/k2/storage/projects/DistroDFW/DFW/charlie/2024/01/08/DIS_20240108_173602.txt'

Dmax = 10

fig = disdro.plot_DSD(filename, Dmax)

# %%
importlib.reload(disdro)

filename = '/net/k2/storage/people/idariash/home/CSU/DFW/data/SWHP/test/DIS_20240108_171901.txt'
'/net/k2/storage/people/idariash/home/CSU/DFW/data/Charlie/20240108/DIS_20240108_171401.txt'
'/net/k2/storage/projects/DistroDFW/DFW/UMASS/SEHP/20240108/DIS_20240108_173401.txt'
'/net/k2/storage/projects/DistroDFW/DFW/charlie/2024/01/08/DIS_20240108_173401.txt'
'/net/k2/storage/projects/DistroDFW/DFW/charlie/2024/01/08/DIS_20240108_173401.txt'
'/net/k2/storage/projects/DistroDFW/DFW/charlie/2024/01/08/DIS_20240108_173501.txt'
'/net/k2/storage/projects/DistroDFW/DFW/charlie/2024/01/08/DIS_20240108_173602.txt'

Dmax = 10

fig = disdro.plot_DSD_falling_velocity(filename, Dmax)
